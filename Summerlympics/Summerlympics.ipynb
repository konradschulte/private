# %%
### MAC!
# Ideas for improvement:
# 1. Restart-Button?
# 2. Ensure that you cannot close Minigame-Windows without someone winning the game
# 3. Shuffle games before start

import PySimpleGUI as sg # Necessary for user interface
import numpy as np       # Only used for arrays
import time

color = 'yellow'
P1 = 'Group 1'
P2 = 'Group 2'
game_name = 'Summerlympics'
Games = {1:'Flipcup',
         2:'I am a peach',
         3:'#Kaputtmachen',
         4:'Flunkyball',
         5:'Spikeball',
         6:'Who am I?',
         7:'Three legged race',
         8:'Beerpong',
         9:'Song Quiz',
         10:'Shithead',
         11:'Bangers',
         12:'Minigolf',
         13:'Tittipong',
         14:'Civil War',
         15:'tba'}

sg.theme_background_color(color) 
sg.theme_text_color('black')
global p1_counter
p1_counter = 0
global p2_counter
p2_counter = 0
global counter
counter = 1

buttons_upper = []
for i in range(1,16):
    buttons_upper.append(sg.pin(sg.Button('', key= str(i)+'D', size = (4,1), visible=False, font=('impact', 20), button_color = 'black',border_width=0)))
    buttons_upper.append(sg.pin(sg.Button(str(i), key= str(i), size = (4,1), visible=True, font=('impact', 20), button_color = 'black',border_width=0)))

player_1 = [[sg.Text(str(P1),background_color=color,pad=(5,5),font=('impact', 50), justification='center')],
            [sg.Text('0', key = 'p1_c',text_color='white',size=(10,1),background_color='black',font=('impact', 50), justification='center')],
            [sg.Text(size=(0,0),background_color=color)],
            [sg.ProgressBar(max_value=61, orientation='h', border_width=4,bar_color=('red',color),size=(25, 20), key='p1_p')],
            [sg.Text(size=(0,0),background_color=color)],
            [sg.Text('1', key = 'p1_1',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('2', key = 'p1_2',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('3', key = 'p1_3',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('4', key = 'p1_4',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('5', key = 'p1_5',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center')],
            [sg.Text('6', key = 'p1_6',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('7', key = 'p1_7',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('8', key = 'p1_8',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('9', key = 'p1_9',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('10', key = 'p1_10',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center')],
            [sg.Text('11', key = 'p1_11',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('12', key = 'p1_12',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('13', key = 'p1_13',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('14', key = 'p1_14',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('15', key = 'p1_15',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center')]
           ]

player_2 = [[sg.Text(str(P2),background_color=color,pad=(5,5),font=('impact', 50), justification='center')],
            [sg.Text('0', key = 'p2_c',text_color='white',size=(10,1),background_color='black',font=('impact', 50), justification='center')],
            [sg.Text(size=(0,0),background_color=color)],
            [sg.ProgressBar(max_value=61, orientation='h', border_width=4,bar_color=('red',color),size=(25, 20), key='p2_p')],
            [sg.Text(size=(0,0),background_color=color)],
            [sg.Text('1', key = 'p2_1',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('2', key = 'p2_2',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('3', key = 'p2_3',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('4', key = 'p2_4',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('5', key = 'p2_5',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center')],
            [sg.Text('6', key = 'p2_6',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('7', key = 'p2_7',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('8', key = 'p2_8',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('9', key = 'p2_9',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('10', key = 'p2_10',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center')],
            [sg.Text('11', key = 'p2_11',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('12', key = 'p2_12',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('13', key = 'p2_13',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('14', key = 'p2_14',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('15', key = 'p2_15',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center')]
           ]

    
def game(): 
    layout = [[sg.Text(game_name, background_color=color, font=('impact', 40, 'underline'), justification='r')],
              [sg.Button(visible=False)],
               buttons_upper,
              [sg.Column([[]], size=(100, 30), background_color=color, element_justification='c')],
              [sg.Column(player_1, size=(350, 480), background_color=color, element_justification='c'),
               sg.Column([[]], size=(100, 380), background_color=color, element_justification='c'),
               sg.Column(player_2, size=(350, 480), background_color=color, element_justification='c')]]
    
    # Define main window (1425, 775)
    window = sg.Window(game_name, layout, size=(1425,775), element_justification='c', \
                       background_color=color, finalize=True, resizable=True, disable_close=True)
   
    def minigame(i):
        lower_m = [[sg.Button(P1, key= 'p1_w_'+str(i), size = (10,1), visible=True, font=('impact', 40), button_color = 'black',border_width=0),
                    sg.Text('',size=(17,1),background_color=color, font=('impact', 28), justification='center'),
                    sg.Text('Who won?',text_color='black',size=(10,1),background_color=color, font=('impact', 60), justification='center'),
                    sg.Text('',size=(17,1),background_color=color, font=('impact', 28), justification='center'),
                    sg.Button(P2, key= 'p2_w_'+str(i), size = (10,1), visible=True, font=('impact', 40), button_color = 'black',border_width=0)
                   ]]
        
        layout_m = [[sg.Text(game_name, background_color=color, size=(20,2), font=('impact', 40, 'underline'), justification='c')],
                    [sg.Button(visible=False)],
                    [sg.Text('Game '+str(i)+':',text_color='black',size=(30,1),background_color=color, font=('impact', 50), justification='c')],
                    [sg.Text(Games[i],text_color='black',size=(40,2),background_color=color, font=('impact', 100), justification='c')],
                    [sg.Column(lower_m, size=(1455, 230), background_color=color, element_justification='c')]]
        
        window_m = sg.Window(game_name, layout_m, size=(1425,775), element_justification='c', \
                           background_color=color, finalize=True)
        # Minigame: Event loop
        while True:
            event, values = window_m.read()
            
            if event == 'p1_w_'+str(i):
                global p1_counter
                p1_counter += i
                window['p1_c'].update(value=str(p1_counter))
                window['p1_p'].update(p1_counter)
                window['p1_'+str(i)].Update(text_color='white')
                break  
            
            if event == 'p2_w_'+str(i):
                global p2_counter
                p2_counter += i
                window['p2_c'].update(value=str(p2_counter))
                window['p2_p'].update(p2_counter)
                window['p2_'+str(i)].Update(text_color='white')
                break
                
            if event == sg.WIN_CLOSED:
                break
        
        window_m.close()
        
    def endgame(name):
        
        lower_e = [[sg.Text('',size=(30,1),background_color=color, font=('impact', 28), justification='center'),
                    sg.Button('Continue Game', key= 'C', size = (17,1), visible=True, font=('impact', 40), button_color = 'black',border_width=0),
                    sg.Text('',size=(32,1),background_color=color, font=('impact', 28), justification='center')]]
        
        layout_e = [[sg.Text(game_name, background_color=color, size=(20,1), font=('impact', 40, 'underline'), justification='c')],
                    [sg.Button(visible=False)],
                    [sg.Text('',text_color='black',size=(30,2),background_color=color, font=('impact', 40), justification='c')],
                    [sg.Text('Congratulations,',text_color='black',size=(80,1),background_color=color, font=('impact', 100), justification='c')],
                    [sg.Text( str(name)+'!',text_color='black',size=(80,1),background_color=color, font=('impact', 100), justification='c')],
                    [sg.Text('',text_color='black',size=(30,1),background_color=color, font=('impact', 40), justification='c')],
                    [sg.Column(lower_e, size=(1455, 230), background_color=color, element_justification='c')]]
        
        window_e = sg.Window(game_name, layout_e, size=(1425,775), element_justification='c', \
                           background_color=color, finalize=True)
        # Minigame: Event loop
        while True:
            event, values = window_e.read()
            
            if event == 'C':
                break
            if event == sg.WIN_CLOSED:
                window.close()
                break
        
        window_e.close()
        
    done = False
    # Game: Event loop
    while True:
        event, values = window.read()
        
        # Open a separate window for the respective calculation 
        for i in range(1,16):
            global counter
            if event == str(i) and counter == i:
                window[str(i)+'D'].Update(visible = True)
                window[str(i)].Update(visible = False)
                counter += 1
                minigame(i)
                
        global p1_counter
        if p1_counter > 60 and done == False:
            time.sleep(5)
            #global done
            done = True
            endgame(P1)
        
        global p2_counter
        if p2_counter > 60 and done == False:
            time.sleep(5)
            #global done
            done = True
            endgame(P2)
        
        # End if user closes window
        if event == sg.WIN_CLOSED:
            break
    
    window.close()
game()
# Out:
# Mac OS Version is 13.0.1 and patch enabled so applying the patch
# Applyting Mac OS 12.3+ Alpha Channel fix.  Your default Alpha Channel is now 0.99

# %%
### WINDOWS!
import PySimpleGUI as sg # Necessary for user interface
import numpy as np       # Only used for arrays
import time

color = 'yellow'
P1 = 'Group 1'
P2 = 'Group 2'
game_name = 'Birthday Battle'
Games = {1:'Flipcup',
         2:'I am a peach',
         3:'Who am I?',
         4:'Flunkyball',
         5:'Spikeball',
         6:'Three legged race',
         7:'Beerpong',
         8:'Music Video',
         9:'Workout',
         10:'Bangers',
         11:'Egg Relay',
         12:'Jeu de boules',
         13:'Civil War',
         14:'Minigolf',
         15:'Yes, No, Uh'}

sg.theme_background_color(color) 
sg.theme_text_color('black')
global p1_counter
p1_counter = 0
global p2_counter
p2_counter = 0
global counter
counter = 1

buttons_upper = []
for i in range(1,16):
    buttons_upper.append(sg.pin(sg.Button('', key= str(i)+'D', size = (4,1), visible=False, font=('impact', 20), button_color = 'black',border_width=0)))
    buttons_upper.append(sg.pin(sg.Button(str(i), key= str(i), size = (4,1), visible=True, font=('impact', 20), button_color = 'black',border_width=0)))

player_1 = [[sg.Text(str(P1),background_color=color,pad=(5,5),font=('impact', 70), justification='center')],
            [sg.Text('0', key = 'p1_c',text_color='white',size=(10,1),background_color='black',font=('impact', 50), justification='center')],
            [sg.Text(size=(0,0),background_color=color)],
            [sg.ProgressBar(max_value=61, orientation='h', border_width=4,bar_color=('red',color),size=(25, 20), key='p1_p')],
            [sg.Text(size=(0,0),background_color=color)],
            [sg.Text('1', key = 'p1_1',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('2', key = 'p1_2',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('3', key = 'p1_3',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('4', key = 'p1_4',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('5', key = 'p1_5',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center')],
            [sg.Text('6', key = 'p1_6',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('7', key = 'p1_7',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('8', key = 'p1_8',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('9', key = 'p1_9',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('10', key = 'p1_10',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center')],
            [sg.Text('11', key = 'p1_11',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('12', key = 'p1_12',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('13', key = 'p1_13',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('14', key = 'p1_14',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('15', key = 'p1_15',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center')]
           ]

player_2 = [[sg.Text(str(P2),background_color=color,pad=(5,5),font=('impact', 70), justification='center')],
            [sg.Text('0', key = 'p2_c',text_color='white',size=(10,1),background_color='black',font=('impact', 50), justification='center')],
            [sg.Text(size=(0,0),background_color=color)],
            [sg.ProgressBar(max_value=61, orientation='h', border_width=4,bar_color=('red',color),size=(25, 20), key='p2_p')],
            [sg.Text(size=(0,0),background_color=color)],
            [sg.Text('1', key = 'p2_1',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('2', key = 'p2_2',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('3', key = 'p2_3',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('4', key = 'p2_4',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('5', key = 'p2_5',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center')],
            [sg.Text('6', key = 'p2_6',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('7', key = 'p2_7',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('8', key = 'p2_8',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('9', key = 'p2_9',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('10', key = 'p2_10',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center')],
            [sg.Text('11', key = 'p2_11',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('12', key = 'p2_12',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('13', key = 'p2_13',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('14', key = 'p2_14',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center'),
             sg.Text('15', key = 'p2_15',text_color='black',size=(3,1),background_color='black', font=('impact', 28), justification='center')]
           ]

    
def game(): 
    layout = [[sg.Text(game_name, background_color=color, font=('impact', 40, 'underline'), justification='r')],
              [sg.Button(visible=False)],
               buttons_upper,
              [sg.Column([[]], size=(100, 30), background_color=color, element_justification='c')],
              [sg.Column(player_1, size=(350, 480), background_color=color, element_justification='c'),
               sg.Column([[]], size=(100, 380), background_color=color, element_justification='c'),
               sg.Column(player_2, size=(350, 480), background_color=color, element_justification='c')]]
    
    # Define main window
    window = sg.Window(game_name, layout, size=(1425,775), element_justification='c', \
                       background_color=color, finalize=True, resizable=True, disable_close=True)
   
    def minigame(i):
        lower_m = [[sg.Button(P1, key= 'p1_w_'+str(i), size = (10,1), visible=True, font=('impact', 40), button_color = 'black',border_width=0),
                    sg.Text('',size=(13,1),background_color=color, font=('impact', 28), justification='center'),
                    sg.Text('Who won?',text_color='black',size=(10,1),background_color=color, font=('impact', 60), justification='center'),
                    sg.Text('',size=(13,1),background_color=color, font=('impact', 28), justification='center'),
                    sg.Button(P2, key= 'p2_w_'+str(i), size = (10,1), visible=True, font=('impact', 40), button_color = 'black',border_width=0)
                   ]]
        
        layout_m = [[sg.Text(game_name, background_color=color, size=(20,2), font=('impact', 40, 'underline'), justification='c')],
                    [sg.Button(visible=False)],
                    [sg.Text('Game '+str(i)+':',text_color='black',size=(30,1),background_color=color, font=('impact', 50), justification='c')],
                    [sg.Text(Games[i],text_color='black',size=(40,2),background_color=color, font=('impact', 100), justification='c')],
                    [sg.Column(lower_m, size=(1455, 230), background_color=color, element_justification='c')]]
        
        window_m = sg.Window(game_name, layout_m, size=(1500,700), element_justification='c', \
                           background_color=color, finalize=True)
        # Minigame: Event loop
        while True:
            event, values = window_m.read()
            
            if event == 'p1_w_'+str(i):
                global p1_counter
                p1_counter += i
                window['p1_c'].update(value=str(p1_counter))
                window['p1_p'].update(p1_counter)
                window['p1_'+str(i)].Update(text_color='white')
                break  
            
            if event == 'p2_w_'+str(i):
                global p2_counter
                p2_counter += i
                window['p2_c'].update(value=str(p2_counter))
                window['p2_p'].update(p2_counter)
                window['p2_'+str(i)].Update(text_color='white')
                break
                
            if event == sg.WIN_CLOSED:
                break
        
        window_m.close()
        
    def endgame(j):
        
        lower_e = [[sg.Text('',size=(28,1),background_color=color, font=('impact', 28), justification='center'),
                    sg.Button('Continue Game', key= 'C', size = (15,1), visible=True, font=('impact', 40), button_color = 'black',border_width=0),
                    sg.Text('',size=(28,1),background_color=color, font=('impact', 28), justification='center')]]
        
        layout_e = [[sg.Text(game_name, background_color=color, size=(20,1), font=('impact', 40, 'underline'), justification='c')],
                    [sg.Button(visible=False)],
                    [sg.Text('',text_color='black',size=(30,1),background_color=color, font=('impact', 40), justification='c')],
                    [sg.Text('Congratulations, \n'+str(j)+'!',text_color='black',size=(40,2),background_color=color, font=('impact', 100), justification='c')],
                    [sg.Text('',text_color='black',size=(30,1),background_color=color, font=('impact', 40), justification='c')],
                    [sg.Column(lower_e, size=(1455, 230), background_color=color, element_justification='c')]]
        
        window_e = sg.Window(game_name, layout_e, size=(1500,700), element_justification='c', \
                           background_color=color, finalize=True)
        # Minigame: Event loop
        while True:
            event, values = window_e.read()
            
            if event == 'C':
                break
            if event == sg.WIN_CLOSED:
                window.close()
                break
        
        window_e.close()
    
    done = False
    # Game: Event loop
    while True:
        event, values = window.read()
        
        # Open a separate window for the respective calculation 
        for i in range(1,16):
            global counter
            if event == str(i) and counter == i:
                window[str(i)+'D'].Update(visible = True)
                window[str(i)].Update(visible = False)
                counter += 1
                minigame(i)
                
        global p1_counter
        if p1_counter > 60 and done == False:
            time.sleep(10)
            #global done
            done = True
            endgame(P1)
        
        global p2_counter
        if p2_counter > 60 and done == False:
            time.sleep(10)
            #global done
            done = True
            endgame(P2)
        
        # End if user closes window
        if event == sg.WIN_CLOSED:
            break
    
    window.close()
game()
# Out:
# Mac OS Version is 13.0.1 and patch enabled so applying the patch
# Applyting Mac OS 12.3+ Alpha Channel fix.  Your default Alpha Channel is now 0.99
